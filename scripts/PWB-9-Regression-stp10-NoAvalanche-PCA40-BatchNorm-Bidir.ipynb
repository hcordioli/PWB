# %% [markdown]
# # Versionamento

# %% [markdown]
# V2:
# <ul>
#     <li>Inclusão da variável categórica x28 que está relacionada com o tipo de papel em produção</li>
#     <li>Feature Selection</li>
#     <li>Feature Scalling</li>
# </ul>

# %% [markdown]
# V3:
# <ul>
#     <li>Ajuste de parâmetros dos modelos</li>
#     <li> V2: correção da função lstm_data_transform para pegar o target correto</li>
# </ul>

# %% [markdown]
# V4:
# <ul>
#     <li>Redução de feature usando resultado do PCA (notebook DimRedPCAOnTS) </li>
# </ul>

# %% [markdown]
# V5:
# <ul>
#     <li>Uso de dataset separado manualmente para treino e teste separado do de validação </li>
#     <li>num_steps de 30 para 10</li>
#     <li>Verificação do comportamento das features entre uma quebra e a próxima</li>
# </ul>

# %% [markdown]
# # O problema

# %% [markdown]
# Paper manufacturing can be viewed as a continuous rolling process. During this process, sometimes the paper breaks. If a break happens, the entire process is stopped, the reel is taken out, any found problem is fixed, and the production is resumed. The resumption can take more than an hour.
#
# The cost of this lost production time is significant for a mill. Even a 5% reduction in the break events will give a significant cost saving for a mill. The objective of the given problem is to predict such breaks in advance (early prediction) and identify the potential cause(s) to prevent the break.
#
# To build such a prediction model, we will use the data collected from the network of sensors in a mill.

# %% [markdown]
# This is a multivariate time series data with break as the response (a
# binary variable).
# The provided data has,
# <ul>
#     <li>18,398 records.</li>
#     <li>Columns:</li>
#         <ul>
#         <li>time: the timestamp of the row</li>
#         <li>y: the binary response variable. There are only 124 rows with y = 1, rest are y = 0.</li>
#         <li>x1-x61: predictor variables. All the predictors are continuous variables, except x28 and x61. x61 is a binary variable, and x28 is a
#         categorical variable. All the predictors are centered. Besides, the predictors are a mixture of raw materials and process variables. Their descriptions are omitted for data anonymity.
#             Several sensors are placed in different parts of the machine along its length
# and breadth. These sensors measure both raw materials (e.g. amount of pulp
# fiber, chemicals, etc.) and process variables (e.g. blade type, couch vacuum,
# rotor speed, etc.).</li>
#         </ul>
# </ul>

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.metrics import confusion_matrix, recall_score, precision_score
import datetime

# %% [markdown]
# # Load Data

# %%
pwbdatafile = '..\\data\\pwb-data-augmented.csv'
pwbds = pd.read_csv(pwbdatafile)

# %%
pwbds.head()
# Out:
#    Unnamed: 0  y        x1        x2        x3         x4        x5  \
# 0           0  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830
# 1           1  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733
# 2           2  0  0.363848 -4.681394 -4.353147  14.127997 -0.138636
# 3           3  0  0.301590 -4.758934 -4.023612  13.161566 -0.148142
# 4           4  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314
#
#           x6        x7        x8  ...       x53       x54        x55  \
# 0 -20.669883  0.000732 -0.061114  ...  0.053279 -4.936434 -24.590146
# 1 -18.758079  0.000732 -0.061114  ...  0.062801 -4.937179 -32.413266
# 2 -17.836632  0.010803 -0.061114  ...  0.072322 -4.937924 -34.183774
# 3 -18.517601  0.002075 -0.061114  ...  0.081600 -4.938669 -35.954281
# 4 -17.505913  0.000732 -0.061114  ...  0.091121 -4.939414 -37.724789
#
#          x56       x57       x58       x59       x60  x61  timestamp
# 0  18.515436  3.473400  0.033444  0.953219  0.006076    0          0
# 1  22.760065  2.682933  0.033536  1.090502  0.006083    0          1
# 2  27.004663  3.537487  0.033629  1.840540  0.006090    0          2
# 3  21.672449  3.986095  0.033721  2.554880  0.006097    0          3
# 4  21.907251  3.601573  0.033777  1.410494  0.006105    0          4
#
# [5 rows x 64 columns]

# %%
pwbds.drop('Unnamed: 0',axis=1,inplace=True)

# %%
pwbds.head()
# Out:
#    y        x1        x2        x3         x4        x5         x6        x7  \
# 0  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830 -20.669883  0.000732
# 1  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733 -18.758079  0.000732
# 2  0  0.363848 -4.681394 -4.353147  14.127997 -0.138636 -17.836632  0.010803
# 3  0  0.301590 -4.758934 -4.023612  13.161566 -0.148142 -18.517601  0.002075
# 4  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314 -17.505913  0.000732
#
#          x8        x9  ...       x53       x54        x55        x56  \
# 0 -0.061114 -0.059966  ...  0.053279 -4.936434 -24.590146  18.515436
# 1 -0.061114 -0.059966  ...  0.062801 -4.937179 -32.413266  22.760065
# 2 -0.061114 -0.030057  ...  0.072322 -4.937924 -34.183774  27.004663
# 3 -0.061114 -0.019986  ...  0.081600 -4.938669 -35.954281  21.672449
# 4 -0.061114 -0.030057  ...  0.091121 -4.939414 -37.724789  21.907251
#
#         x57       x58       x59       x60  x61  timestamp
# 0  3.473400  0.033444  0.953219  0.006076    0          0
# 1  2.682933  0.033536  1.090502  0.006083    0          1
# 2  3.537487  0.033629  1.840540  0.006090    0          2
# 3  3.986095  0.033721  2.554880  0.006097    0          3
# 4  3.601573  0.033777  1.410494  0.006105    0          4
#
# [5 rows x 63 columns]

# %%
# Now, the target
pwbds.y.value_counts()
# Out:
# 0    52538
# 1      363
# Name: y, dtype: int64

# %% [markdown]
# ## Cálculo do Remaining Usefull Lifecycle (RUL)

# %%
# Dates whith break
df_sub = sorted(pwbds[pwbds['y'] == 1]['timestamp'].tolist())

# %%
df_sub
# Out:
# [259,
#  776,
#  835,
#  1036,
#  1263,
#  1301,
#  1339,
#  1344,
#  1719,
#  1750,
#  2121,
#  2298,
#  2303,
#  2308,
#  2312,
#  2317,
#  2335,
#  2366,
#  2374,
#  2378,
#  2407,
#  2591,
#  2599,
#  2645,
#  2714,
#  2738,
#  2826,
#  2921,
#  2945,
#  2963,
#  2971,
#  2999,
#  3522,
#  3598,
#  3600,
#  3748,
#  4018,
#  4177,
#  4797,
#  4933,
#  5457,
#  6220,
#  6823,
#  7147,
#  7173,
#  7243,
#  7609,
#  7843,
#  7939,
#  7946,
#  8022,
#  8072,
#  8083,
#  8130,
#  8221,
#  8236,
#  8475,
#  8933,
#  9101,
#  9148,
#  9153,
#  9196,
#  9203,
#  9412,
#  9431,
#  9523,
#  9842,
#  10037,
#  10163,
#  10241,
#  10798,
#  10817,
#  10837,
#  10893,
#  11152,
#  11503,
#  11551,
#  11574,
#  11743,
#  11751,
#  11792,
#  11829,
#  11867,
#  12324,
#  13081,
#  13614,
#  14029,
#  14138,
#  14160,
#  14516,
#  14914,
#  15096,
#  15294,
#  15413,
#  15436,
#  15456,
#  15483,
#  15520,
#  15526,
#  15531,
#  15567,
#  15590,
#  15644,
#  15647,
#  15663,
#  15669,
#  15705,
#  15709,
#  15739,
#  15770,
#  15806,
#  15926,
#  16259,
#  16693,
#  16923,
#  17033,
#  17182,
#  17205,
#  17293,
#  17476,
#  17605,
#  17758,
#  18282,
#  18601,
#  18737,
#  18743,
#  18831,
#  19015,
#  19245,
#  19427,
#  19483,
#  19488,
#  20108,
#  20631,
#  20826,
#  20921,
#  20944,
#  21053,
#  21173,
#  21506,
#  21584,
#  21843,
#  22241,
#  22329,
#  22348,
#  22352,
#  22378,
#  22469,
#  22696,
#  22734,
#  22758,
#  22787,
#  22955,
#  23558,
#  23599,
#  23607,
#  23703,
#  23734,
#  23758,
#  23906,
#  23956,
#  24133,
#  24138,
#  24572,
#  24610,
#  24633,
#  24661,
#  24665,
#  24673,
#  24678,
#  24837,
#  24868,
#  24905,
#  25271,
#  25301,
#  25321,
#  25329,
#  25787,
#  25825,
#  26059,
#  26062,
#  26069,
#  26602,
#  26728,
#  27052,
#  27467,
#  27485,
#  27504,
#  27522,
#  27544,
#  27613,
#  27621,
#  27675,
#  27711,
#  28067,
#  28126,
#  28146,
#  28238,
#  28243,
#  28700,
#  28829,
#  29030,
#  29066,
#  29176,
#  29733,
#  30250,
#  30399,
#  30774,
#  30821,
#  31578,
#  31761,
#  31777,
#  32037,
#  32042,
#  32065,
#  32067,
#  32098,
#  32174,
#  32179,
#  32186,
#  32262,
#  32289,
#  32293,
#  32502,
#  32517,
#  32686,
#  32697,
#  32740,
#  33091,
#  33210,
#  33233,
#  33270,
#  33316,
#  34079,
#  34126,
#  34396,
#  34767,
#  35006,
#  35012,
#  35048,
#  35096,
#  35294,
#  35613,
#  35643,
#  35690,
#  35698,
#  35703,
#  35753,
#  35757,
#  36172,
#  36267,
#  36303,
#  36349,
#  36437,
#  36620,
#  36953,
#  36958,
#  36996,
#  37235,
#  37417,
#  37453,
#  37458,
#  37567,
#  37590,
#  37616,
#  37619,
#  37970,
#  38058,
#  38207,
#  38226,
#  38624,
#  38883,
#  38911,
#  38918,
#  38936,
#  38941,
#  38965,
#  39498,
#  39667,
#  39703,
#  39851,
#  39889,
#  40492,
#  41049,
#  41283,
#  41359,
#  41377,
#  41385,
#  41511,
#  42131,
#  42168,
#  42602,
#  42678,
#  42732,
#  43256,
#  44013,
#  44240,
#  44267,
#  44287,
#  44324,
#  44367,
#  44723,
#  44754,
#  44813,
#  44869,
#  45064,
#  45084,
#  45252,
#  45322,
#  45442,
#  45899,
#  45995,
#  46225,
#  46988,
#  47010,
#  47015,
#  47053,
#  47064,
#  47070,
#  47271,
#  47340,
#  47469,
#  47561,
#  47759,
#  48217,
#  48308,
#  48683,
#  48706,
#  48737,
#  48896,
#  48915,
#  49124,
#  49448,
#  49453,
#  49455,
#  49463,
#  49723,
#  50240,
#  50288,
#  50424,
#  50601,
#  50617,
#  50623,
#  50733,
#  50740,
#  50859,
#  51230,
#  51254,
#  51295,
#  51661,
#  51665,
#  51712,
#  51735,
#  51766,
#  52036,
#  52065,
#  52588,
#  52603,
#  52626,
#  52630,
#  52708,
#  52892,
#  52900]

# %%
# variable to store all days
breakSubIdx=0
breakLstIdx=0
breakList = pwbds['y'].tolist()
nextbreak = []
for v1 in pwbds['timestamp'].tolist():
    if((breakList[breakLstIdx] == 1)):
#        print ('1')
        nextbreak.append(v1)
        breakSubIdx = breakSubIdx+1
    else:
#        print('0')
        if (breakSubIdx < len(df_sub)):
            nextbreak.append(df_sub[breakSubIdx])
        else:
            nextbreak.append(df_sub[breakSubIdx-1])
    breakLstIdx = breakLstIdx+1
pwbds['nextbreaktime'] = pd.Series(nextbreak)

# %%
pwbds.head()
# Out:
#    y        x1        x2        x3         x4        x5         x6        x7  \
# 0  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830 -20.669883  0.000732
# 1  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733 -18.758079  0.000732
# 2  0  0.363848 -4.681394 -4.353147  14.127997 -0.138636 -17.836632  0.010803
# 3  0  0.301590 -4.758934 -4.023612  13.161566 -0.148142 -18.517601  0.002075
# 4  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314 -17.505913  0.000732
#
#          x8        x9  ...       x54        x55        x56       x57  \
# 0 -0.061114 -0.059966  ... -4.936434 -24.590146  18.515436  3.473400
# 1 -0.061114 -0.059966  ... -4.937179 -32.413266  22.760065  2.682933
# 2 -0.061114 -0.030057  ... -4.937924 -34.183774  27.004663  3.537487
# 3 -0.061114 -0.019986  ... -4.938669 -35.954281  21.672449  3.986095
# 4 -0.061114 -0.030057  ... -4.939414 -37.724789  21.907251  3.601573
#
#         x58       x59       x60  x61  timestamp  nextbreaktime
# 0  0.033444  0.953219  0.006076    0          0            259
# 1  0.033536  1.090502  0.006083    0          1            259
# 2  0.033629  1.840540  0.006090    0          2            259
# 3  0.033721  2.554880  0.006097    0          3            259
# 4  0.033777  1.410494  0.006105    0          4            259
#
# [5 rows x 64 columns]

# %%
pwbds['RUL']=(pwbds['nextbreaktime']-pwbds['timestamp'])
#pwbds.drop(pwbds[pwbds.RUL < 0].index, inplace=True)
pwbds.drop(['timestamp','nextbreaktime'], axis=1, inplace=True)

# %%
pwbds.iloc[257:262,]
# Out:
#      y        x1         x2         x3         x4        x5         x6  \
# 257  0  1.005602  -3.876199  -1.074373   0.844397 -0.553050  14.738228
# 258  0  0.933933  -3.868467  -1.249954   2.875311 -0.500941  15.643990
# 259  1  0.892311 -13.332664 -10.006578   2.855933 -0.448832  15.986336
# 260  0  0.020062  -3.987897  -1.248529 -72.927591  0.956625 -52.225319
# 261  0 -0.109346  -5.071100  -2.409911 -68.501153  0.008764 -49.642799
#
#            x7        x8        x9  ...        x53       x54        x55  \
# 257  0.000732 -0.061114 -0.030057  ...  -0.752385 -5.015364 -69.553891
# 258  0.000732 -0.061114 -0.030057  ...  -0.752385 -5.015458 -75.298153
# 259  0.000732 -0.061114 -0.030057  ...  -0.752385 -5.015553 -75.896664
# 260  0.000732 -0.061114 -0.030057  ... -14.211369 -5.159890 -96.241513
# 261  0.000732 -0.061114 -0.030057  ... -14.153996 -5.159059 -67.912900
#
#            x56       x57       x58       x59       x60  x61  RUL
# 257  70.500879  4.050182  0.031596  3.746714  0.007695    0    2
# 258  68.812829  3.473400  0.032007  4.712130  0.007679    0    1
# 259  69.585016  3.113292  0.032223  5.685793  0.007663    1    0
# 260 -10.347296  5.853832  0.023872  5.635012  0.006604    0  516
# 261  -4.702612  5.975902  0.021971  5.245829  0.006588    0  515
#
# [5 rows x 63 columns]

# %% [markdown]
# ### Verificando cálculo do RUL

# %%
pwbds[pwbds.y==1]
# Out:
#        y        x1         x2         x3          x4        x5         x6  \
# 259    1  0.892311 -13.332664 -10.006578    2.855933 -0.448832  15.986336
# 776    1 -0.782471 -12.118747 -16.855194 -322.781610 -0.738810  25.966042
# 835    1 -0.697450  -1.696176   4.145142  121.152838 -0.598597  -7.789024
# 1036   1 -0.791718  -0.076644  -1.012134  162.257269 -0.062876   9.005471
# 1263   1 -1.212083  -2.326809   0.922287   31.935858 -0.920100  14.183205
# ...   ..       ...        ...        ...         ...       ...        ...
# 52626  1 -0.367076  -8.876281  -9.826331  -81.548181  0.719656 -31.805839
# 52630  1  0.381548  -7.119146  -7.791697  -68.089395  0.172140 -61.932670
# 52708  1  0.386066  -9.029249  -8.759439   83.883705 -0.509745  52.357521
# 52892  1 -0.082568  -8.880742 -16.979639   61.011024 -0.183390  26.041847
# 52900  1 -0.132460   0.664956  -9.645391  -70.156457 -0.163660 -62.941185
#
#              x7        x8        x9  ...        x53       x54         x55  \
# 259    0.000732 -0.061114 -0.030057  ...  -0.752385 -5.015553  -75.896664
# 776    0.040711 -0.071186  0.012574  ...  -5.337590  2.680329   -7.209775
# 835    0.060853  0.048752 -0.120087  ...  -6.368351  2.568616  -26.245907
# 1036   0.005767  0.033764 -0.120087  ...  -6.856144  2.703874  -29.833432
# 1263  -0.089298  0.028915 -0.120087  ...  -6.856144  2.762956    0.965763
# ...         ...       ...       ...  ...        ...       ...         ...
# 52626 -0.058545 -0.000993  0.009922  ...  10.091365  3.105512  101.055728
# 52630  0.000732 -0.101094  0.009922  ...   5.405574 -5.013181  -46.756772
# 52708  0.180791  0.268791  0.139931  ...   1.914363  3.143712   18.257755
# 52892 -0.059389 -0.091023 -0.040129  ...   3.983455 -4.996303  -31.832699
# 52900  0.000732 -0.111165 -0.070037  ...   4.488338 -4.995505  -29.216122
#
#              x56       x57       x58       x59       x60  x61  RUL
# 259    69.585016  3.113292  0.032223  5.685793  0.007663    1    0
# 776   -37.195777  1.642284  0.013798  2.664362  0.007856    0    0
# 835   -74.477362 -0.097279  0.015905  2.700281  0.007745    0    0
# 1036  -53.421866 -1.165393  0.019691  3.348276  0.006241    0    0
# 1263  -49.512961 -0.219349  0.041640  2.740404  0.005131    0    0
# ...          ...       ...       ...       ...       ...  ...  ...
# 52626 -59.396201 -2.111499  0.001227  1.458925  0.018978    0    0
# 52630 -52.525641 -0.860218  0.016202  3.409899  0.007643    0    0
# 52708 -72.250327 -1.775806 -0.149790 -0.102720  0.000803    1    0
# 52892  54.449090  3.473400  0.011233  1.377375  0.007596    0    0
# 52900 -54.312064 -0.860218  0.013202  2.419375  0.007412    0    0
#
# [363 rows x 63 columns]

# %%
pwbds.iloc[257:262,][['y','RUL']]
# Out:
#      y  RUL
# 257  0    2
# 258  0    1
# 259  1    0
# 260  0  516
# 261  0  515

# %%
pwbds.drop(pwbds[pwbds.RUL < 0].index, inplace=True)

# %%
pwbds.iloc[257:262,][['y','RUL']]
# Out:
#      y  RUL
# 257  0    2
# 258  0    1
# 259  1    0
# 260  0  516
# 261  0  515

# %%
pwbds.head(100)
# Out:
#     y        x1        x2        x3         x4        x5         x6        x7  \
# 0   0  0.376665 -4.596435 -4.095756  13.497687 -0.118830 -20.669883  0.000732
# 1   0  0.475720 -4.542502 -4.018359  16.230659 -0.128733 -18.758079  0.000732
# 2   0  0.363848 -4.681394 -4.353147  14.127997 -0.138636 -17.836632  0.010803
# 3   0  0.301590 -4.758934 -4.023612  13.161566 -0.148142 -18.517601  0.002075
# 4   0  0.265578 -4.749928 -4.333150  15.267340 -0.155314 -17.505913  0.000732
# .. ..       ...       ...       ...        ...       ...        ...       ...
# 95  0  0.338822 -5.022894 -2.608153 -20.503778 -0.017481 -44.553459  0.020874
# 96  0  0.308304 -5.194098 -2.751440 -19.194543  0.008062 -46.399620  0.020874
# 97  0  0.308107 -5.090988 -2.761078 -19.517114  0.033590 -47.134178  0.020874
# 98  0  0.336788 -5.116952 -2.638822 -20.037836  0.059133 -47.633186  0.020874
# 99  0  0.217240 -5.237374 -2.870212 -21.021844  0.084676 -44.996986  0.020874
#
#           x8        x9  ...       x53       x54        x55        x56  \
# 0  -0.061114 -0.059966  ...  0.053279 -4.936434 -24.590146  18.515436
# 1  -0.061114 -0.059966  ...  0.062801 -4.937179 -32.413266  22.760065
# 2  -0.061114 -0.030057  ...  0.072322 -4.937924 -34.183774  27.004663
# 3  -0.061114 -0.019986  ...  0.081600 -4.938669 -35.954281  21.672449
# 4  -0.061114 -0.030057  ...  0.091121 -4.939414 -37.724789  21.907251
# ..       ...       ...  ...       ...       ...        ...        ...
# 95 -0.051043 -0.059966  ... -0.199894 -5.000089 -37.394345  -6.514594
# 96 -0.051043 -0.059966  ... -0.204289 -5.000183 -42.467709  -7.359717
# 97 -0.051043 -0.059966  ... -0.208684 -5.000278 -49.438046  -3.726843
# 98 -0.051043 -0.059966  ... -0.213078 -5.000372 -39.797299  -3.818945
# 99 -0.061114 -0.059966  ... -0.217228 -5.000467 -36.600888  -5.891577
#
#          x57       x58       x59       x60  x61  RUL
# 0   3.473400  0.033444  0.953219  0.006076    0  259
# 1   2.682933  0.033536  1.090502  0.006083    0  258
# 2   3.537487  0.033629  1.840540  0.006090    0  257
# 3   3.986095  0.033721  2.554880  0.006097    0  256
# 4   3.601573  0.033777  1.410494  0.006105    0  255
# ..       ...       ...       ...       ...  ...  ...
# 95  4.434703  0.029854  1.558092  0.006878    0  164
# 96  3.473400  0.029434  0.888880  0.006887    0  163
# 97  3.473400  0.029229  1.255404  0.006896    0  162
# 98  3.973888  0.029696  2.018366  0.006905    0  161
# 99  3.992198  0.030163  2.488749  0.006914    0  160
#
# [100 rows x 63 columns]

# %% [markdown]
# ### Remove Break Avalanche

# %%
def removeBreakAvalanche (fullds):
    clean_ds = pd.DataFrame([])
    breaks = np.array(np.where(pwbds['y'] == 1)).reshape(-1)
    start = 0 
    for breakpt in breaks:
        if (breakpt-start >= 30):
            clean_ds = clean_ds.append(fullds.iloc[start:breakpt+1,],ignore_index = True)
        start = breakpt+1
    return (clean_ds)

# %%
clean_ds = removeBreakAvalanche(pwbds)

# %% [markdown]
# # Feature Selection and Scaling

# %%
# Feature Selection
# List of considered Features

FEATURES = [
#    'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20',
#    'x21','x22','x23','x24','x25,''x26','x27','x28','x29','x30','x31','x32','x33','x34','x35','x36','x37','x38','x39','x40',
#    'x41','x42','x43','x44','x45','x46','x47','x48','x49','x50','x51','x52','x53','x54','x55','x56','x57','x58','x59','x60'
#]
# Redução de feature usando resultado do PCA (notebook DimRedPCAOnTS)
#    'x1','x5','x8','x10','x13','x14','x15','x17','x18','x19','x20','x21','x22','x26','x28','x30','x31','x34',
#    'x35','x37','x38','x40','x41','x43','x46','x48','x49','x51','x53','x54','x55','x58'

# Usando as features com base na sua relação com RUL
#    'x4','x24','x48','x58','x60','x42','x45','x61','x46','x49','x9','x10','x38','x17','x5','x28','x33','x41',   
#    'x13','x16','x56','x8','x12','x1','x57','x50','x44','x47','x52','x27','x37','x3','x54','x26','x2','x29','x55'

# Cj 1 - Não usar: derrubou métricas quando adicionado ao Cj 4 + Cj 6
#    'x1','x2','x4','x5','x6','x7','x10', 'x11','x13','x15','x17','x28',
#    'x1','x5','x10','x13','x14','x15',
    
# Cj 2
# Medidos sem C3:
#    'x3','x8','x10','x12','x13','x16','x18','x19','x20','x23','x25', # Precision: 0.781, Recall: 0.390, F1: 0.520
#    'x3','x8','x10','x12','x13','x16',                               # Precision: 0.834, Recall: 0.375, F1: 0.518
#    'x18','x19','x20','x23','x25',                                   # Precision: 0.980, Recall: 0.156, F1: 0.269
#    'x3','x8','x10','x18','x19','x20',                               # Precision: 0.848, Recall: 0.251, F1: 0.387
#    'x12','x13','x16','x23','x25',                                   # Precision: 0.900, Recall: 0.218, F1: 0.351
# Medidos com C3:
    'x3','x8','x10','x12','x13','x16','x18','x19','x20','x23','x25',  # Precision: 0.735, Recall: 0.470, F1: 0.573

    # Cj 3
   'x9','x21','x22','x24','x26','x27','x29','x30',                   # Precision: 0.735, Recall: 0.470, F1: 0.573
#    'x9','x21','x22','x24',                                          # Precision: 0.785, Recall: 0.451, F1: 0.573
#    'x26','x27','x29','x30',                                         # Precision: 0.766, Recall: 0.406, F1: 0.530
#    'x9','x21','x29','x30',                                          # Precision: 0.742, Recall: 0.353, F1: 0.478
#    'x22','x24','x26','x27',                                          # Precision: 0.801, Recall: 0.383, F1: 0.518   
    
# Cj 4
    'x28','x36','x37','x38','x39','x40','x31','x32','x33','x34','x35',
    
# Cj 5
#    'x41','x42','x43','x44','x45','x46','x47','x48','x49','x52',

# Cj 6
   'x50','x51','x53','x54','x55','x56','x57','x58','x59','x60'
]

# Create the dataset with features and filter the data to the list of FEATURES
pwbds_filtered = clean_ds[FEATURES]

# Print the tail of the dataframe
pwbds_filtered.tail()
# Out:
#               x3        x8       x10       x12        x13       x16       x18  \
# 51207  -4.299529 -0.091023  0.001791 -0.027113  33.072848 -0.861594 -1.321521
# 51208  -4.205272 -0.091023 -0.001682 -0.043949  27.396365 -0.858991 -1.321521
# 51209  -4.257756 -0.091023 -0.008280 -0.041273  30.298602 -0.842231 -1.321521
# 51210  -6.632444 -0.091023 -0.008280 -0.102537  27.852786 -0.939992 -1.321521
# 51211 -16.979639 -0.091023 -0.008280  0.000849  28.922030 -0.910653 -1.321521
#
#             x19       x20       x23  ...        x50        x51       x53  \
# 51207  3.229279 -0.187979 -5.780428  ...  12.798573  27.413823  4.041316
# 51208  3.224604 -0.182428 -5.780428  ...  12.807850  27.467778  4.026912
# 51209  3.219929 -0.176877 -5.780428  ...  12.817372  27.521489  4.012264
# 51210  3.215254 -0.171326 -5.780428  ...  12.826893  27.575444  3.997859
# 51211  3.210579 -0.165775 -5.780428  ...  12.836171  27.629399  3.983455
#
#             x54        x55        x56       x57       x58       x59       x60
# 51207 -4.996629 -31.080624  60.825372  4.114269  0.011547  1.405894  0.007603
# 51208 -4.996548 -31.341977  58.203699  4.114269  0.011469  0.341051  0.007601
# 51209 -4.996466 -31.505551  55.582056  3.473400  0.011390  0.110140  0.007599
# 51210 -4.996385 -31.669125  54.916864  4.175304  0.011312  0.718683  0.007598
# 51211 -4.996303 -31.832699  54.449090  3.473400  0.011233  1.377375  0.007596
#
# [5 rows x 40 columns]

# %%
# This Scaler removes the median and scales the data according to the quantile range to normalize the price data 
from sklearn.preprocessing import RobustScaler, MinMaxScaler 

# Get the number of rows in the data
nrows = pwbds_filtered.shape[0]

# Convert the data to numpy values
np_data_unscaled = np.array(pwbds_filtered)
np_data = np.reshape(np_data_unscaled, (nrows, -1))
print(np_data.shape)

# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data_scaled = scaler.fit_transform(np_data_unscaled)
pwbds_scaled = pd.DataFrame(
    np_data_scaled,
    columns=FEATURES
)
pwbds_scaled['RUL'] = clean_ds['RUL']
# Out:
# (51212, 40)

# %% [markdown]
# # Shaping & Splitting

# %%
def lstm_data_transform(x_data, y_data, num_steps=5):
    """ Changes data to the format for LSTM training for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        
        # if index is larger than the size of the dataset, we stop
        if end_ix > x_data.shape[0]:
            break
        
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix-1]
        
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %% [markdown]
# ## Dataset for Model 1

# %%
pwbds_m1 = pwbds_scaled.copy()
#pwbds_m1.drop('NEXT_H',axis='columns', inplace=True)
yds_m1 = pwbds_m1.pop('RUL')

# %% [markdown]
# ## Apply PCA

# %%
from sklearn.decomposition import PCA # for PCA calculation
pca = PCA()
X_pca = pca.fit(pwbds_m1)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
num_components = 40
pca = PCA(num_components)  
X_pca = pca.fit_transform(pwbds_m1) # fit and reduce dimension

# %%
X_pca.shape
# Out:
# (51212, 40)

# %%
num_steps = 10 # Intervalo entre medições é de 2 segundos
x_new, y_new = lstm_data_transform(X_pca, yds_m1, num_steps=num_steps)
print ("The new shape of x is", x_new.shape)
# Out:
# The new shape of x is (51203, 10, 40)

# %%
train_ind = int(0.7 * clean_ds.shape[0])
x_train = x_new[:train_ind]
y_train = y_new[:train_ind]
x_test = x_new[train_ind:]
y_test = y_new[train_ind:]

# %% [markdown]
# # Modeling 1: Regression - Predict RUL

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
print(tf. __version__)
print(np. __version__)
from platform import python_version

print(python_version())
# Out:
# 1.14.0
# 1.19.5
# 3.6.9

# %% [markdown]
# ### Discussão sobre o significado de UNITS em LSTM
#
# https://stackoverflow.com/questions/44273249/in-keras-what-exactly-am-i-configuring-when-i-create-a-stateful-lstm-layer-wi#:~:text=Basically%2C%20the%20unit%20means%20the,be%20unit%20%2Dlength%20as%20well.

# %%
model_1 = keras.Sequential()
model_1.add(layers.Bidirectional(layers.LSTM(120, activation='tanh', input_shape=(num_steps, x_train.shape[2]), 
               return_sequences=True)))
model_1.add(layers.BatchNormalization())

# Plus a 20% dropout rate
model_1.add(layers.Dropout(0.2))

# The second layer
model_1.add(layers.Bidirectional(layers.LSTM(
          units=60,
          return_sequences=False)))
model_1.add(layers.BatchNormalization())

# Plus a 20% dropout rate
model_1.add(layers.Dropout(0.2))
model_1.add(layers.Dense(units=60, activation='relu'))
model_1.add(layers.Dropout(0.2))
model_1.add(layers.Dense(units=30, activation='relu'))
model_1.add(layers.Dropout(0.2))
model_1.add(layers.Dense(units=1, activation='linear'))

# With adam optimizer and a binary crossentropy loss. We will opimize for model accuracy.
adam = keras.optimizers.Adam(lr=0.0001)
adagrad = keras.optimizers.Adagrad(learning_rate=0.0001,initial_accumulator_value=0.1, epsilon=1e-07)
rmsprop = keras.optimizers.RMSprop(learning_rate=0.0001,rho=0.9, momentum=0.001, epsilon=1e-07)

model_1.compile(optimizer=adam, loss='mse', metrics=['mse'])
# Out:
# WARNING:tensorflow:From C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# EarlyStopping Callback
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

history_m1 = model_1.fit(
    x_train, 
    y_train, 
    epochs=60,
    callbacks=[callback],
#    batch_size=60, 
    validation_split=0.10 # Use 10% of data to evaluate the loss. (val_loss)
)
# Out:
# Train on 32263 samples, validate on 3585 samples
# WARNING:tensorflow:From C:\Users\hcord\anaconda3\envs\paper3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/60
# 32263/32263 [==============================] - 36s 1ms/sample - loss: 35089.1762 - mean_squared_error: 35089.1797 - val_loss: 8022.1636 - val_mean_squared_error: 8022.1621
# Epoch 2/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 9349.8779 - mean_squared_error: 9349.8809 - val_loss: 5316.1577 - val_mean_squared_error: 5316.1582
# Epoch 3/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 7284.2941 - mean_squared_error: 7284.2886 - val_loss: 4238.6574 - val_mean_squared_error: 4238.6572
# Epoch 4/60
# 32263/32263 [==============================] - 35s 1ms/sample - loss: 6237.9954 - mean_squared_error: 6237.9946 - val_loss: 4061.4652 - val_mean_squared_error: 4061.4656
# Epoch 5/60
# 32263/32263 [==============================] - 39s 1ms/sample - loss: 5444.1676 - mean_squared_error: 5444.1685 - val_loss: 3387.6047 - val_mean_squared_error: 3387.6055
# Epoch 6/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 5223.0658 - mean_squared_error: 5223.0659 - val_loss: 3082.7287 - val_mean_squared_error: 3082.7288
# Epoch 7/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 4784.1219 - mean_squared_error: 4784.1240 - val_loss: 2687.6754 - val_mean_squared_error: 2687.6763
# Epoch 8/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 4526.7661 - mean_squared_error: 4526.7695 - val_loss: 2357.5683 - val_mean_squared_error: 2357.5684
# Epoch 9/60
# 32263/32263 [==============================] - 36s 1ms/sample - loss: 4282.2925 - mean_squared_error: 4282.2939 - val_loss: 1834.3298 - val_mean_squared_error: 1834.3298
# Epoch 10/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 4136.5163 - mean_squared_error: 4136.5161 - val_loss: 1894.4681 - val_mean_squared_error: 1894.4684
# Epoch 11/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 3914.8348 - mean_squared_error: 3914.8347 - val_loss: 1792.7491 - val_mean_squared_error: 1792.7487
# Epoch 12/60
# 32263/32263 [==============================] - 36s 1ms/sample - loss: 3828.4897 - mean_squared_error: 3828.4905 - val_loss: 1741.4812 - val_mean_squared_error: 1741.4813
# Epoch 13/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3624.0795 - mean_squared_error: 3624.0771 - val_loss: 1647.1970 - val_mean_squared_error: 1647.1969
# Epoch 14/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 3669.5220 - mean_squared_error: 3669.5232 - val_loss: 1391.1047 - val_mean_squared_error: 1391.1047
# Epoch 15/60
# 32263/32263 [==============================] - 39s 1ms/sample - loss: 3414.9293 - mean_squared_error: 3414.9309 - val_loss: 1607.3229 - val_mean_squared_error: 1607.3228
# Epoch 16/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3331.1590 - mean_squared_error: 3331.1599 - val_loss: 1624.8628 - val_mean_squared_error: 1624.8627
# Epoch 17/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3164.3940 - mean_squared_error: 3164.3950 - val_loss: 1312.3448 - val_mean_squared_error: 1312.3446
# Epoch 18/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3400.3206 - mean_squared_error: 3400.3228 - val_loss: 1348.9390 - val_mean_squared_error: 1348.9386
# Epoch 19/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3117.7790 - mean_squared_error: 3117.7791 - val_loss: 1324.7819 - val_mean_squared_error: 1324.7819
# Epoch 20/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3061.5740 - mean_squared_error: 3061.5752 - val_loss: 1199.9217 - val_mean_squared_error: 1199.9219
# Epoch 21/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 3089.8603 - mean_squared_error: 3089.8606 - val_loss: 1561.0705 - val_mean_squared_error: 1561.0707
# Epoch 22/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2935.2827 - mean_squared_error: 2935.2815 - val_loss: 1270.5212 - val_mean_squared_error: 1270.5214
# Epoch 23/60
# 32263/32263 [==============================] - 39s 1ms/sample - loss: 2902.6648 - mean_squared_error: 2902.6675 - val_loss: 1188.4483 - val_mean_squared_error: 1188.4485
# Epoch 24/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2968.2401 - mean_squared_error: 2968.2405 - val_loss: 1280.4574 - val_mean_squared_error: 1280.4572
# Epoch 25/60
# 32263/32263 [==============================] - 39s 1ms/sample - loss: 2850.4605 - mean_squared_error: 2850.4583 - val_loss: 1223.9035 - val_mean_squared_error: 1223.9038
# Epoch 26/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2730.2769 - mean_squared_error: 2730.2800 - val_loss: 1140.6542 - val_mean_squared_error: 1140.6543
# Epoch 27/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2774.0800 - mean_squared_error: 2774.0808 - val_loss: 1114.9512 - val_mean_squared_error: 1114.9510
# Epoch 28/60
# 32263/32263 [==============================] - 40s 1ms/sample - loss: 2662.9647 - mean_squared_error: 2662.9656 - val_loss: 1070.8854 - val_mean_squared_error: 1070.8855
# Epoch 29/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2729.6068 - mean_squared_error: 2729.6072 - val_loss: 1110.7697 - val_mean_squared_error: 1110.7697
# Epoch 30/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2638.0055 - mean_squared_error: 2638.0066 - val_loss: 1018.0346 - val_mean_squared_error: 1018.0346
# Epoch 31/60
# 32263/32263 [==============================] - 39s 1ms/sample - loss: 2664.6928 - mean_squared_error: 2664.6914 - val_loss: 2135.8526 - val_mean_squared_error: 2135.8528
# Epoch 32/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2511.5237 - mean_squared_error: 2511.5247 - val_loss: 1415.9211 - val_mean_squared_error: 1415.9210
# Epoch 33/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2554.4731 - mean_squared_error: 2554.4734 - val_loss: 949.7198 - val_mean_squared_error: 949.7196
# Epoch 34/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2515.5443 - mean_squared_error: 2515.5452 - val_loss: 1001.7709 - val_mean_squared_error: 1001.7710
# Epoch 35/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2510.7920 - mean_squared_error: 2510.7922 - val_loss: 985.9000 - val_mean_squared_error: 985.9002
# Epoch 36/60
# 32263/32263 [==============================] - 42s 1ms/sample - loss: 2429.7787 - mean_squared_error: 2429.7776 - val_loss: 978.1812 - val_mean_squared_error: 978.1812
# Epoch 37/60
# 32263/32263 [==============================] - 40s 1ms/sample - loss: 2527.9753 - mean_squared_error: 2527.9761 - val_loss: 879.7763 - val_mean_squared_error: 879.7762
# Epoch 38/60
# 32263/32263 [==============================] - 39s 1ms/sample - loss: 2388.4165 - mean_squared_error: 2388.4160 - val_loss: 955.5689 - val_mean_squared_error: 955.5687
# Epoch 39/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2373.8777 - mean_squared_error: 2373.8782 - val_loss: 1055.4005 - val_mean_squared_error: 1055.4005
# Epoch 40/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2400.8064 - mean_squared_error: 2400.8062 - val_loss: 935.8694 - val_mean_squared_error: 935.8696
# Epoch 41/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2344.3144 - mean_squared_error: 2344.3147 - val_loss: 907.5246 - val_mean_squared_error: 907.5245
# Epoch 42/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2313.1313 - mean_squared_error: 2313.1331 - val_loss: 996.5580 - val_mean_squared_error: 996.5579
# Epoch 43/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2349.0754 - mean_squared_error: 2349.0754 - val_loss: 884.9148 - val_mean_squared_error: 884.9149
# Epoch 44/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2316.1812 - mean_squared_error: 2316.1814 - val_loss: 1203.8222 - val_mean_squared_error: 1203.8220
# Epoch 45/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2306.7224 - mean_squared_error: 2306.7234 - val_loss: 996.4662 - val_mean_squared_error: 996.4661
# Epoch 46/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2239.7121 - mean_squared_error: 2239.7114 - val_loss: 1087.2998 - val_mean_squared_error: 1087.2999
# Epoch 47/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2284.4196 - mean_squared_error: 2284.4204 - val_loss: 1639.5222 - val_mean_squared_error: 1639.5221
# Epoch 48/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2201.7653 - mean_squared_error: 2201.7666 - val_loss: 925.6761 - val_mean_squared_error: 925.6761
# Epoch 49/60
# 32263/32263 [==============================] - 42s 1ms/sample - loss: 2267.8460 - mean_squared_error: 2267.8459 - val_loss: 960.8002 - val_mean_squared_error: 960.8000
# Epoch 50/60
# 32263/32263 [==============================] - 45s 1ms/sample - loss: 2236.8900 - mean_squared_error: 2236.8892 - val_loss: 896.4180 - val_mean_squared_error: 896.4181
# Epoch 51/60
# 32263/32263 [==============================] - 42s 1ms/sample - loss: 2161.8483 - mean_squared_error: 2161.8486 - val_loss: 984.5555 - val_mean_squared_error: 984.5554
# Epoch 52/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2210.3709 - mean_squared_error: 2210.3711 - val_loss: 853.5862 - val_mean_squared_error: 853.5860
# Epoch 53/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2186.2314 - mean_squared_error: 2186.2324 - val_loss: 811.6101 - val_mean_squared_error: 811.6102
# Epoch 54/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2158.6078 - mean_squared_error: 2158.6084 - val_loss: 866.4955 - val_mean_squared_error: 866.4954
# Epoch 55/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2165.1450 - mean_squared_error: 2165.1443 - val_loss: 870.7814 - val_mean_squared_error: 870.7818
# Epoch 56/60
# 32263/32263 [==============================] - 38s 1ms/sample - loss: 2156.8137 - mean_squared_error: 2156.8142 - val_loss: 1031.7053 - val_mean_squared_error: 1031.7052
# Epoch 57/60
# 32263/32263 [==============================] - 37s 1ms/sample - loss: 2144.9811 - mean_squared_error: 2144.9814 - val_loss: 1098.1428 - val_mean_squared_error: 1098.1426
# Epoch 58/60
# 32263/32263 [==============================] - 36s 1ms/sample - loss: 2070.3155 - mean_squared_error: 2070.3152 - val_loss: 1337.4464 - val_mean_squared_error: 1337.4463
# Epoch 59/60
# 32263/32263 [==============================] - 35s 1ms/sample - loss: 2076.7205 - mean_squared_error: 2076.7197 - val_loss: 770.9697 - val_mean_squared_error: 770.9697
# Epoch 60/60
# 32263/32263 [==============================] - 35s 1ms/sample - loss: 2120.3956 - mean_squared_error: 2120.3958 - val_loss: 892.4596 - val_mean_squared_error: 892.4596

# %%
# Verify the architecture 
print(model_1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional multiple                  154560
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  960
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# bidirectional_1 (Bidirection multiple                  144480
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  480
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  7260
# _________________________________________________________________
# dropout_2 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  1830
# _________________________________________________________________
# dropout_3 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  31
# =================================================================
# Total params: 309,601
# Trainable params: 308,881
# Non-trainable params: 720
# _________________________________________________________________
# None

# %%
# Plot History
pd.DataFrame(history_m1.history).plot()
plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
model_1.evaluate(x_test, y_test, verbose=1)
# Out:
# 15355/15355 [==============================] - 2s 158us/sample - loss: 938.2633 - mean_squared_error: 938.2632
# [938.2632542293726, 938.26324]

# %%
test_predict = model_1.predict(x_test)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://www.aaai.org/Papers/Symposia/Spring/2002/SS-02-03/SS02-03-012.pdf

# %%
figure(figsize=(15, 6), dpi=80)
plt.xlabel('Timestamp')
plt.ylabel('RUL')
plt.plot(y_test,'r+',label="real")
plt.plot(test_predict,'b+',label="predict")
plt.legend(['real', 'predict'], loc='upper right')

# %%
results = pd.DataFrame(y_test)
results['preds']=test_predict
results.columns=['true','preds']
results['dif']=round(results['true']-results['preds'],2)
results.to_csv('results.csv')

# %%
results.describe()
# Out:
#                true         preds           dif
# count  15355.000000  15355.000000  15355.000000
# mean     189.394464    184.055481      5.338986
# std      163.028551    164.399017     30.163202
# min        0.000000      9.454865   -475.460000
# 25%       58.000000     45.234636     -5.505000
# 50%      142.000000    136.847794      5.770000
# 75%      286.000000    280.714996     14.845000
# max      762.000000    779.767944    728.130000

# %%
x_train.shape
# Out:
# (35848, 10, 40)

# %% [markdown]
# ## Análise do Erro

# %%
import math
errordf = pd.DataFrame(y_test,columns=['real'])
errordf['pred']=test_predict
errordf['e_squared']=(errordf['real']-errordf['pred'])**2
errordf['e_squared']= errordf['e_squared'].astype('float')
total_rmse = math.sqrt(errordf['e_squared'].sum()/len(errordf['e_squared']))

# %%
total_rmse
# Out:
# 30.6310832119038

# %%
errordf['error'] = np.sqrt(errordf['e_squared'])

# %% [markdown]
# ### Nos dados de testes existem 64 instantes de quebra de papel

# %%
np.unique(y_test==0,return_counts=True)
# Out:
# (array([False,  True]), array([15285,    70], dtype=int64))

# %%
len(errordf.loc[errordf['real']==0])
# Out:
# 70

# %% [markdown]
# ### Previsões corretas de quebra

# %%
len(errordf.loc[errordf['pred']==0])
# Out:
# 0

# %%
measurements=0
errordf.loc[(errordf['real'] <= measurements) & (errordf['pred'] <= measurements) ]
# Out:
# Empty DataFrame
# Columns: [real, pred, e_squared, error]
# Index: []

# %% [markdown]
# ### Previsões corretas de quebra dentro de intervalos de tempo

# %%
# 30 medições equivalem a 60 minutos (2 minutos por medição)
measurements=30
len (errordf.loc[(errordf['real'] == 0) & (errordf['pred'] <= measurements) ])
# Out:
# 38

# %%
# 60 medições equivalem a 120 minutos (2 minutos por medição)
measurements=60
len (errordf.loc[(errordf['real'] == 0) & (errordf['pred'] <= measurements) ])
# Out:
# 59

# %%
# 90 medições equivalem a 180 minutos (2 minutos por medição)
measurements=90
len (errordf.loc[(errordf['real'] == 0) & (errordf['pred'] <= measurements) ])
# Out:
# 64

# %% [markdown]
# ### Porém o modelo estaria avisando falsamente:

# %%
measurements=30
len(errordf.loc[(errordf['real'] > measurements) & (errordf['pred'] <= measurements)])
# Out:
# 829

# %%
measurements=60
len(errordf.loc[(errordf['real'] > measurements) & (errordf['pred'] <= measurements)])
# Out:
# 846

# %%
measurements=90
len(errordf.loc[(errordf['real'] > measurements) & (errordf['pred'] <= measurements)])
# Out:
# 596

# %% [markdown]
# ## Truth

# %% [markdown]
# ### Quantas quebras realmente ocorreram?

# %%
# Registro de quebras são aqueles onde RUL==0 (y_test==0)
np.unique(y_test==0,return_counts=True)
# Out:
# (array([False,  True]), array([15285,    70], dtype=int64))

# %% [markdown]
# ### Quando ocorreram?

# %%
break_moments= np.where(y_test == 0)

# %%
list(break_moments)
# Out:
# [array([  200,   382,   418,   527,   878,   966,  1115,  1513,  1772,
#          2305,  2474,  2510,  2658,  2696,  3299,  3856,  4090,  4166,
#          4292,  4912,  4949,  5383,  5459,  5513,  6037,  6794,  7021,
#          7058,  7101,  7457,  7488,  7547,  7603,  7798,  7966,  8036,
#          8156,  8613,  8709,  8939,  9702,  9740,  9941, 10010, 10139,
#         10231, 10429, 10887, 10978, 11353, 11384, 11543, 11752, 12076,
#         12336, 12853, 12901, 13037, 13214, 13324, 13443, 13814, 13855,
#         14221, 14268, 14299, 14569, 15092, 15170, 15354], dtype=int64)]

# %% [markdown]
# ## Previsões

# %% [markdown]
# ### Quantas indicações abaixo de x minutos?

# %%
np.unique(test_predict <= measurements ,return_counts=True)
# Out:
# (array([False,  True]), array([9384, 5971], dtype=int64))

# %% [markdown]
# ### Quando ocorreram?

# %%
np.where(test_predict <= measurements)[0]
# Out:
# array([  101,   102,   104, ..., 15352, 15353, 15354], dtype=int64)

# %% [markdown]
# ## Acertos
# ### Quantos e quando?

# %%
when_pred = np.where(test_predict <= measurements)[0].tolist()
when_true = np.where(y_test == 0)[0].tolist()

# %%
commonalities = set(when_pred) - (set(when_pred) - set(when_true))

# %%
len(commonalities)
# Out:
# 64

# %%
commonalities
# Out:
# {200,
#  382,
#  418,
#  527,
#  878,
#  966,
#  1115,
#  1513,
#  1772,
#  2305,
#  2474,
#  2510,
#  2658,
#  2696,
#  3299,
#  3856,
#  4090,
#  4166,
#  4292,
#  4912,
#  4949,
#  5459,
#  5513,
#  6794,
#  7021,
#  7058,
#  7101,
#  7457,
#  7488,
#  7547,
#  7603,
#  7798,
#  7966,
#  8036,
#  8156,
#  8709,
#  8939,
#  9740,
#  9941,
#  10010,
#  10139,
#  10231,
#  10429,
#  10887,
#  10978,
#  11353,
#  11384,
#  11543,
#  11752,
#  12076,
#  12336,
#  12853,
#  12901,
#  13214,
#  13324,
#  13443,
#  13814,
#  13855,
#  14221,
#  14268,
#  14569,
#  15092,
#  15170,
#  15354}

# %%
import shap  # package used to calculate Shap values

# use Deep SHAP to explain test set predictions
#k_explainer = shap.KernelExplainer(model_1.predict_proba, x_test)
#k_shap_values = k_explainer.shap_values(x_test.reshape(14315*30,32))
#shap.force_plot(k_explainer.expected_value[1], k_shap_values[1], x_test)

# %% [markdown]
# # Salvando o modelo

# %%
model_1.save('../data/pwb_regression-10stps-noavalanche-pca40-batchnormal-bidir')
