# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.metrics import confusion_matrix, recall_score, precision_score
import random

# %% [markdown]
# # Load dataset

# %%
pwbdatafile = '..\\data\\pwb-data.csv'
pwbds = pd.read_csv(pwbdatafile)
pwbds.drop(['time'],axis=1,inplace=True)
pwbds.shape
# Out:
# (17689, 62)

# %%
len(pwbds.loc[pwbds.y==1])
# Out:
# 121

# %% [markdown]
# # Isola cada série

# %%
brks = pwbds.loc[pwbds.y==1]

# %%
start=0
end=260
tmp = pwbds.iloc[start:end+1,:]

# %%
brkseries = list()
start=0
for brk_idx, brk in brks.iterrows():
    tmp = pwbds.iloc[start:brk_idx+1,:]
    brkseries.append(tmp)
    start = brk_idx+1

# %% [markdown]
# # Augment original dataset randomly

# %%
for i in range (2):
    new_series = random.sample(range(0, len(brks)), len(brks))
    for new_serie in new_series:
        pwbds = pwbds.append(brkseries[new_serie])

# %%
pwbds.shape
# Out:
# (52901, 62)

# %%
pwbds.loc[pwbds.y==1]
# Out:
#        y        x1         x2         x3          x4        x5         x6  \
# 259    1  0.892311 -13.332664 -10.006578    2.855933 -0.448832  15.986336
# 776    1 -0.782471 -12.118747 -16.855194 -322.781610 -0.738810  25.966042
# 835    1 -0.697450  -1.696176   4.145142  121.152838 -0.598597  -7.789024
# 1036   1 -0.791718  -0.076644  -1.012134  162.257269 -0.062876   9.005471
# 1263   1 -1.212083  -2.326809   0.922287   31.935859 -0.920100  14.183205
# ...   ..       ...        ...        ...         ...       ...        ...
# 11574  1 -0.367076  -8.876281  -9.826331  -81.548181  0.719656 -31.805839
# 2378   1  0.381548  -7.119146  -7.791697  -68.089395  0.172140 -61.932670
# 10241  1  0.386066  -9.029249  -8.759439   83.883705 -0.509745  52.357521
# 2591   1 -0.082568  -8.880742 -16.979639   61.011024 -0.183390  26.041847
# 2374   1 -0.132460   0.664956  -9.645391  -70.156457 -0.163660 -62.941185
#
#              x7        x8        x9  ...        x52        x53       x54  \
# ...

# %%
pwbds.tail()
# Out:
#       y        x1        x2        x3         x4        x5         x6  \
# 2370  0 -0.242336  0.414705 -2.370209 -71.828012 -0.253245 -62.316429
# 2371  0 -0.162291  0.538814 -2.258692 -68.548181 -0.230845 -61.560692
# 2372  0 -0.323937  0.555539 -2.118908 -72.603738 -0.208460 -62.111641
# 2373  0 -0.280295  0.643592 -2.565778 -72.206201 -0.186060 -62.881447
# 2374  1 -0.132460  0.664956 -9.645391 -70.156457 -0.163660 -62.941185
#
#             x7        x8        x9  ...       x52       x53       x54  \
# 2370  0.030640 -0.121236 -0.070037  ... -1.497635  4.258846 -4.991085
# 2371  0.013489 -0.121236 -0.070037  ... -1.472733  4.316219 -4.992190
# 2372  0.002746 -0.111165 -0.070037  ... -1.447830  4.373592 -4.993295
# 2373  0.000732 -0.111165 -0.070037  ... -1.422928  4.430965 -4.994400
# 2374  0.000732 -0.111165 -0.070037  ... -1.398026  4.488338 -4.995505
#
#             x55        x56       x57       x58       x59       x60  x61
# ...

# %%
pwbds.reset_index(level=0, inplace=True)

# %%
pwbds.tail()
# Out:
#        index  y        x1        x2        x3         x4        x5         x6  \
# 52896   2370  0 -0.242336  0.414705 -2.370209 -71.828012 -0.253245 -62.316429
# 52897   2371  0 -0.162291  0.538814 -2.258692 -68.548181 -0.230845 -61.560692
# 52898   2372  0 -0.323937  0.555539 -2.118908 -72.603738 -0.208460 -62.111641
# 52899   2373  0 -0.280295  0.643592 -2.565778 -72.206201 -0.186060 -62.881447
# 52900   2374  1 -0.132460  0.664956 -9.645391 -70.156457 -0.163660 -62.941185
#
#              x7        x8  ...       x52       x53       x54        x55  \
# 52896  0.030640 -0.121236  ... -1.497635  4.258846 -4.991085 -20.881161
# 52897  0.013489 -0.121236  ... -1.472733  4.316219 -4.992190 -22.384335
# 52898  0.002746 -0.111165  ... -1.447830  4.373592 -4.993295 -22.384335
# 52899  0.000732 -0.111165  ... -1.422928  4.430965 -4.994400 -22.384335
# 52900  0.000732 -0.111165  ... -1.398026  4.488338 -4.995505 -29.216122
#
#              x56       x57       x58       x59       x60  x61
# ...

# %%
pwbds = pwbds.drop(columns=['index'],axis=1)

# %%
pwbds['timestamp']=pwbds.index

# %%
pwbds.head()
# Out:
#    y        x1        x2        x3         x4        x5         x6        x7  \
# 0  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830 -20.669883  0.000732
# 1  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733 -18.758079  0.000732
# 2  0  0.363848 -4.681394 -4.353147  14.127998 -0.138636 -17.836632  0.010803
# 3  0  0.301590 -4.758934 -4.023612  13.161567 -0.148142 -18.517601  0.002075
# 4  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314 -17.505913  0.000732
#
#          x8        x9  ...       x53       x54        x55        x56  \
# 0 -0.061114 -0.059966  ...  0.053279 -4.936434 -24.590146  18.515436
# 1 -0.061114 -0.059966  ...  0.062801 -4.937179 -32.413266  22.760065
# 2 -0.061114 -0.030057  ...  0.072322 -4.937924 -34.183774  27.004663
# 3 -0.061114 -0.019986  ...  0.081600 -4.938669 -35.954281  21.672449
# 4 -0.061114 -0.030057  ...  0.091121 -4.939414 -37.724789  21.907251
#
#         x57       x58       x59       x60  x61  timestamp
# ...

# %%
pwbds.to_csv('../data/pwb-data-augmented.csv')

# %%
pwbds.shape
# Out:
# (52901, 63)

# %%
pwbds.head()
# Out:
#    y        x1        x2        x3         x4        x5         x6        x7  \
# 0  0  0.376665 -4.596435 -4.095756  13.497687 -0.118830 -20.669883  0.000732
# 1  0  0.475720 -4.542502 -4.018359  16.230659 -0.128733 -18.758079  0.000732
# 2  0  0.363848 -4.681394 -4.353147  14.127998 -0.138636 -17.836632  0.010803
# 3  0  0.301590 -4.758934 -4.023612  13.161567 -0.148142 -18.517601  0.002075
# 4  0  0.265578 -4.749928 -4.333150  15.267340 -0.155314 -17.505913  0.000732
#
#          x8        x9  ...       x53       x54        x55        x56  \
# 0 -0.061114 -0.059966  ...  0.053279 -4.936434 -24.590146  18.515436
# 1 -0.061114 -0.059966  ...  0.062801 -4.937179 -32.413266  22.760065
# 2 -0.061114 -0.030057  ...  0.072322 -4.937924 -34.183774  27.004663
# 3 -0.061114 -0.019986  ...  0.081600 -4.938669 -35.954281  21.672449
# 4 -0.061114 -0.030057  ...  0.091121 -4.939414 -37.724789  21.907251
#
#         x57       x58       x59       x60  x61  timestamp
# ...
